# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = [45, 55, 60, 65, 70, 75, 80, 85, 90, 95]

# %%
#mean  Average
mean=sum(data)/len(data)

# %%
mean
# Out:
# 72.0

# %%
#median  #series is used for single column
median=pd.Series(data).median()

# %%
median
# Out:
# np.float64(72.5)

# %%
std=pd.Series(data).std()

# %%
std
# Out:
# np.float64(16.020819787597222)

# %%
#sample variance ddof = delta degree of freedom
sv=np.var(data,ddof=2)

# %%
sv
# Out:
# np.float64(288.75)

# %%
#entire data variance
sv1=np.var(data)

# %%
sv1
# Out:
# np.float64(231.0)

# %%
#range
r=max(data)-min(data)

# %%
r
# Out:
# 50

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     0
# 0  45
# 1  55
# 2  60
# 3  65
# 4  70
# 5  75
# 6  80
# 7  85
# 8  90
# 9  95

# %%
#Q1 is 25 th percentile

# %%
q1=np.percentile(data,25)

# %%
q1
# Out:
# np.float64(61.25)

# %%
#q2 is 50th percentile or also called as median 
q2=np.percentile(data,50)

# %%
q2
# Out:
# np.float64(72.5)

# %%
#q3 is 75th percentile
q3=np.percentile(data,75)

# %%
q3
# Out:
# np.float64(83.75)

# %%
#can fine any number percentile 
q4=np.percentile(data,30)

# %%
q4
# Out:
# np.float64(63.5)

# %%
#IQR Inter Quartile Range IQR=q3-q1
iqr=q3-q1

# %% [raw]
# iqr

# %%
#lower bound and upper bound
#Outlier boundaries
lowerbound=q1-1.5*iqr

# %%
upperbound=q3+1.5*iqr

# %%
lowerbound
# Out:
# np.float64(27.5)

# %%
upperbound
# Out:
# np.float64(117.5)

# %%
#Statistics is the science of collecting, organizing, analyzing, interpreting, and presenting data.
#4 types of statistics
#descriptive statistics - based on historic data
#inferential statistics - Make predictions or generalizations about a population based on a sample.

# %%
plt.figure(figsize=(4,5))
sns.heatmap(b)
plt.title("heat map ")
# Out:
# Text(0.5, 1.0, 'heat map ')

# %%
#digonal 
b=df.corr()
