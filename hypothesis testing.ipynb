# %%
#hypothesis testing
#1.Null hypothesis -h0 eg : work from home is good 
#2.Alternate hypothesis - h1 eg :work from home is not good 
#p_value(critical value)<5% or >5%

# %%
#T - test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy import stats

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\netha\appdata\local\programs\python\python313\lib\site-packages (from scipy) (2.3.0)
# Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl (38.4 MB)
#    ---------------------------------------- 0.0/38.4 MB ? eta -:--:--
#    ------- -------------------------------- 7.6/38.4 MB 46.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 11.3/38.4 MB 33.1 MB/s eta 0:00:01
#    -------------- ------------------------- 14.2/38.4 MB 23.3 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/38.4 MB 20.0 MB/s eta 0:00:02
#    --------------- ------------------------ 15.2/38.4 MB 15.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.7/38.4 MB 12.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.3/38.4 MB 11.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.8/38.4 MB 10.3 MB/s eta 0:00:03
#    ------------------ --------------------- 17.6/38.4 MB 9.3 MB/s eta 0:00:03
#    ------------------ --------------------- 18.1/38.4 MB 8.8 MB/s eta 0:00:03
#    ------------------- -------------------- 19.1/38.4 MB 8.2 MB/s eta 0:00:03
#    -------------------- ------------------- 19.9/38.4 MB 7.9 MB/s eta 0:00:03
#    --------------------- ------------------ 20.7/38.4 MB 7.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.8/38.4 MB 7.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.8/38.4 MB 7.2 MB/s eta 0:00:03
#    ------------------------ --------------- 23.9/38.4 MB 7.0 MB/s eta 0:00:03
#    ------------------------- -------------- 24.9/38.4 MB 7.0 MB/s eta 0:00:02
#    --------------------------- ------------ 26.2/38.4 MB 6.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.8/38.4 MB 6.9 MB/s eta 0:00:02
#    ------------------------------ --------- 29.1/38.4 MB 6.8 MB/s eta 0:00:02
#    ------------------------------- -------- 30.7/38.4 MB 6.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.2/38.4 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.8/38.4 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.4 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.4 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.4/38.4 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
np.random.seed(42)

# %%
sample = np.random.normal(loc=503, scale=5, size=30)
sample
# Out:
# array([499.99146694, 512.26139092, 502.93251388, 497.71144536,
#        507.11272456, 496.89578175, 504.04431798, 493.20164938,
#        496.35906976, 503.98430618, 506.6923329 , 503.85684141,
#        502.42175859, 501.49448152, 495.60739005, 499.40077896,
#        500.69680615, 508.28561113, 504.71809145, 494.18479922,
#        504.62041985, 501.0745886 , 499.61539   , 506.05838144,
#        508.15499761, 507.6564006 , 498.80391238, 501.45393812,
#        504.65631716, 507.87772564])

# %%
t_statistic, p_value = stats.ttest_1samp(sample, popmean=500)

# %%
print("T-statistic:", t_statistic)
# Out:
# T-statistic: 2.5064402725654054

# %%
print("P-value:", p_value)
# Out:
# P-value: 0.018054505756327662

# %%
a=.05

# %%
#decision
if p_value < a:
    print("work from home is good")
else:
    print("work from home not good.")
# Out:
# work from home is good

# %%
# Simulate a sample of 50 student scores
np.random.seed(42)
sample = np.random.normal(loc=72, scale=5, size=50)

# %%
sample
# Out:
# array([74.48357077, 71.30867849, 75.23844269, 79.61514928, 70.82923313,
#        70.82931522, 79.89606408, 75.83717365, 69.65262807, 74.71280022,
#        69.68291154, 69.67135123, 73.20981136, 62.43359878, 63.37541084,
#        69.18856235, 66.9358444 , 73.57123666, 67.45987962, 64.93848149,
#        79.32824384, 70.8711185 , 72.33764102, 64.87625907, 69.27808638,
#        72.55461295, 66.24503211, 73.87849009, 68.99680655, 70.54153125,
#        68.99146694, 81.26139092, 71.93251388, 66.71144536, 76.11272456,
#        65.89578175, 73.04431798, 62.20164938, 65.35906976, 72.98430618,
#        75.6923329 , 72.85684141, 71.42175859, 70.49448152, 64.60739005,
#        68.40077896, 69.69680615, 77.28561113, 73.71809145, 63.18479922])

# %%
pop_mean=70
pop_std=5

# %%
sample_mean =np.mean(sample)
n=len(sample)

# %%
sample_mean
# Out:
# np.float64(70.8726304737193)

# %%
n
# Out:
# 50

# %%
z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

# %%
z_score
# Out:
# np.float64(1.2340858508738894)

# %%
p_value=2*(1-stats.norm.cdf(abs(z_score)))

# %%
# Calculate p-value 
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
print("Sample Mean:", sample_mean)
print("Z-score:", z_score)
print("P-value:", p_value)
# Out:
# Sample Mean: 70.8726304737193
# Z-score: 1.2340858508738894
# P-value: 0.21717091532783694

# %%
# Decision
alpha = 0.05
if p_value < alpha:
    print("Reject H₀: Sample mean is significantly different from 70.")
else:
    print("Fail to reject H₀: No significant difference from 70.")
# Out:
# Fail to reject H₀: No significant difference from 70.
